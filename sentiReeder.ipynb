# %% [markdown]
# <a href="https://colab.research.google.com/github/abhy-kumar/NLPulse/blob/main/sentiReeder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install feedparser TextBlob
# !pip install nltk transformers torch

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import requests
import feedparser

nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# Custom lexicon for financial and sports terms
custom_lexicon = {
    "boost": 2.0,
    "enhance": 1.5,
    "increase": 1.5,
    "limit": 0.0,  # Neutral in financial context
    "transaction": 0.0,  # Neutral in financial context
    "complicating": -0.5,  # Less negative in sports context
    "must win": 0.0,  # Neutral in sports context
    "contenders": 0.5,  # Slightly positive in sports context
}

sia.lexicon.update(custom_lexicon)

def analyze_sentiment(text, category):
    # NLTK VADER sentiment analysis with custom lexicon
    vader_score = sia.polarity_scores(text)

    # FinBERT sentiment analysis
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    outputs = model(**inputs)
    finbert_score = torch.nn.functional.softmax(outputs.logits, dim=1)
    finbert_sentiment = torch.argmax(finbert_score).item() - 1  # FinBERT returns 0-2 score

    # Combine VADER and FinBERT scores
    combined_score = (vader_score['compound'] + 1) * 2.5  # Convert to 0-10 scale
    combined_score = (combined_score + (finbert_sentiment + 1) * 3.33) / 2  # Average with FinBERT score

    # Adjust score based on category
    if category == "finance":
        combined_score = min(10, combined_score * 1.2)  # Boost finance scores slightly
    elif category == "sports":
        if "win" in text.lower() or "qualify" in text.lower():
            combined_score = min(10, combined_score * 1.1)  # Boost positive sports news

    return combined_score

def categorize_news(title, summary):
    if any(word in title.lower() + summary.lower() for word in ["upi", "rbi", "transaction", "financial", "economy"]):
        return "finance"
    elif any(word in title.lower() + summary.lower() for word in ["cricket", "world cup", "sport", "game", "match"]):
        return "sports"
    else:
        return "general"

def fetch_news_and_analyze(url):
    response = requests.get(url)
    feed = feedparser.parse(response.content)

    daily_scores = []

    for entry in feed.entries:
        print(f"Title: {entry.title}")
        print(f"Published: {entry.published}")
        print(f"Summary: {entry.summary}")

        category = categorize_news(entry.title, entry.summary)
        score = analyze_sentiment(entry.summary, category)
        daily_scores.append(score)

        print(f"Category: {category}")
        print(f"Sentiment Score: {score:.2f}")
        print("---")

    return daily_scores

# Usage
url = "https://timesofindia.indiatimes.com/rssfeedstopstories.cms"
scores = fetch_news_and_analyze(url)
average_score = sum(scores) / len(scores)
print(f"Average sentiment score for today: {average_score:.2f}")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Title: J&K: Body of jawan abducted by terrorists found with 'gunshot wounds'
# Published: Wed, 09 Oct 2024 12:00:27 +0530
# Summary: In Jammu and Kashmir's Anantnag district, security forces have recovered the bullet-riddled body of missing Territorial Army soldier Hilal Ahmad Bhat from the Sanglan forest area. Bhat was allegedly abducted, and his disappearance prompted extensive search operations. Meanwhile, a recent anti-terrorist operation in Kupwara saw the neutralization of two terrorists.
# Category: general
# Sentiment Score: 1.91
# ---
# Title: 'Art of turning victory into defeat ... ': Shiv Sena on Congress's Haryana debacle
# Published: Wed, 09 Oct 2024 12:35:05 +0530
# Summary: Shiv Sena's Saamana editorial criticizes Congress's overconfidence and internal conflicts as reasons for their loss in Haryana elections. It suggests Congress mismanaged a favorable anti-BJP sentiment. Other INDIA bloc partners, including AAP and CPI, also question Congress's approach and advocate for seat sharing in elections to avoid similar outcomes.
# Category: general
# Sentiment Score: 2.44
# ---
# Title: Exclusive: 'Lack of intent from India in T20 WC a cause of concern'
# Published: Wed, 09 Oct 2024 12:34:34 +0530
# Summary: India's Women's T20 World Cup campaign faces a crucial turning point after one win and one loss. They must win against Sri Lanka and Australia convincingly to keep semi-final hopes alive. Ahead of the two pivotal matches, TimesofIndia.com spoke to former India player Reema Malhotra on the campaign so far and way forward.
# Category: sports
# Sentiment Score: 6.31
# ---
# Title: Kolkata rape-murder: CBI chargesheet reveals disturbing details
# Published: Wed, 09 Oct 2024 04:17:00 +0530
# Summary: The RG Kar rape-murder trial involving Sanjay Roy, accused of the Aug 9 crime against a junior doctor, starts Nov 4. The CBI charge sheet details evidence including DNA matches, forensic findings, and injury analysis. Roy, who maintains his innocence, awaits trial where he will be represented by his lawyer.
# Category: finance
# Sentiment Score: 4.47
# ---
# Title: 'Godfather of AI' gets Nobel Prize in Physics; shares his big AI worry
# Published: Wed, 09 Oct 2024 11:28:31 +0530
# Summary: Geoffrey Hinton and John J. Hopfield have received the Nobel Prize in Physics for pioneering work on artificial neural networks. Their research laid the groundwork for current AI systems like ChatGPT. Hinton also warned about potential risks of AI, emphasizing the need for safety research to keep AI under human control.
# Category: general
# Sentiment Score: 5.40
# ---
# Title: India's playing XI vs B'desh: Will they stick to the winning combination?
# Published: Wed, 09 Oct 2024 11:27:13 +0530
# Summary: A spirited Indian team gears up to face Bangladesh in the second T20I in Delhi after a dominant seven-wicket win in Gwalior. With India unlikely to change their winning lineup, key players like Arshdeep Singh and Hardik Pandya, who took a practice day off, are expected to clinch the series with another solid performance.
# Category: general
# Sentiment Score: 2.39
# ---
# Title: Hoodannit? Haryana results mystery leaves Congress clueless
# Published: Wed, 09 Oct 2024 01:13:46 +0530
# Summary: In a surprising twist, BJP secured a comfortable majority in the Haryana elections, obtaining 48 seats against Congress's 37, despite strong anti-incumbency. Congress faced internal issues and miscalculations, while BJP's successful strategy targeted OBC voters and fragmented Dalit votes, ensuring a third consecutive term.
# Category: general
# Sentiment Score: 2.35
# ---
# Title: Stunning visuals from space show Hurricane Milton swirling over Earth
# Published: Wed, 09 Oct 2024 10:28:27 +0530
# Summary: The International Space Station captured a view of Hurricane Milton, which re-intensified into a Category 5 storm, heading towards Florida. NOAA researchers are collecting data to improve forecasts, with the storm expected to hit the Tampa Bay area by October 9 or 10. Satellites reveal the hurricane’s extreme convection currents and small, powerful eye.
# Category: general
# Sentiment Score: 5.44
# ---
# Title: US may be planning to break-up Google, gets this Dec deadline
# Published: Wed, 09 Oct 2024 11:32:01 +0530
# Summary: The US Department of Justice is considering breaking up Google's business segments as a remedy in its antitrust case, following a ruling that declared Google holds an illegal monopoly in the search market.
# Category: general
# Sentiment Score: 2.85
# ---
# Title: New UPI transaction limits announced! Check here
# Published: Wed, 09 Oct 2024 10:44:31 +0530
# Summary: RBI governor Shaktikanta Das announced enhancements to UPI transaction limits, boosting the per transaction limit for UPI 123Pay and increasing the UPI Lite wallet limit.
# Category: finance
# Sentiment Score: 2.01
# ---
# Title: Arshdeep on the brink of breaking Bumrah, Bhuvneshwar records
# Published: Wed, 09 Oct 2024 11:43:32 +0530
# Summary: Arshdeep Singh, India's left-arm pacer, is set to potentially become the nation's second-highest T20I wicket-taker during the ongoing series against Bangladesh. With 86 wickets, he needs just four more to surpass Jasprit Bumrah and Bhuvneshwar Kumar. India’s next two matches are critical for Arshdeep's milestone achievement.
